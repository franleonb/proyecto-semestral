# %%
import pandas as pd
df = pd.read_csv("database_limpia.csv")
df.head(80)
# Out:
#          CANASTA TRADICIONAL            Unnamed: 1  \
# 0                   PRODUCTO                 MARCA
# 1               Arroz blanco                Tottus
# 2   Pan corriente (Hallulla)                Tottus
# 3         Espirales (fideos)               Carozzi
# 4            Harina de trigo            Mont Blanc
# ..                       ...                   ...
# 75         Proteína de soya              Mi Tierra
# 76           Nuggets veganos            La Crianza
# 77        Hamburguesa vegana            La Crianza
# 78           Croqueta vegana  La Receta del Abuelo
# 79              Pollo vegano                     -
#
#                     Unnamed: 2             Unnamed: 3
# 0   PRECIO SUPERMERCADO TOTTUS  CANTIDAD DEL PRODUCTO
# 1                    $1,550.00                   1 kg
# 2                       $2,090                   1 kg
# 3                       $1,050                 400 gr
# 4                       $1,300                   1 kg
# ...
